# %% [markdown]
# <a href="https://colab.research.google.com/github/herdinsavira/Pemrograman-Berorientasi-Objek/blob/main/JOBSHEET_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Praktikum 01 & Penugasan A

# %%
# %%writefile lokasi_semarang.csv
# Nama,Latitude,Longitude,Tipe,Deskripsi
# Lawang Sewu,-6.9840,110.4105,Wisata Sejarah,Bangunan bersejarah peninggalan Belanda dengan banyak pintu.
# Simpang Lima,-6.9929,110.4200,Landmark,"Alun-alun pusat kota Semarang, tempat berkumpul populer."
# Masjid Agung Jawa Tengah,-6.9892,110.4452,Tempat Ibadah,Masjid besar dengan arsitektur megah dan menara pandang Asmaul Husna.
# Klenteng Sam Poo Kong,-6.9980,110.4030,Tempat Ibadah,Klenteng bersejarah peninggalan Laksamana Cheng Ho.
# Brown Canyon,-7.0375,110.4875,Wisata Alam,"Tebing bekas penambangan galian C yang unik menyerupai Grand Canyon."
# Lumpia Gang Lombok,-6.9718,110.4255,Kuliner,Salah satu tempat makan lumpia legendaris dan otentik di Semarang.
# Kota Lama,-6.9690,110.4250,Wisata Sejarah,"Kawasan cagar budaya dengan bangunan-bangunan kuno bergaya Eropa."
# Pantai Marina,-6.9585,110.3875,Wisata Alam,Kawasan pantai rekreasi di bagian utara kota.
# Kampoeng Kopi Banaran,-7.2780,110.4010,Wisata Alam,"Agrowisata kebun kopi dengan pemandangan dan restoran."
# Toko Oen,-6.9715,110.4235,Kuliner,Restoran dan toko es krim legendaris sejak zaman kolonial.
# Museum Ranggawarsita,-7.0012,110.3842,Museum,Museum yang menyimpan berbagai koleksi benda bersejarah dan budaya Jawa Tengah.
# Museum Mandala Bhakti,-6.9845,110.4092,Museum,Museum perjuangan TNI yang terletak tepat di depan Tugu Muda Semarang.
# Taman Indonesia Kaya,-6.9921,110.4225,Taman Kota,Taman umum dengan panggung seni terbuka pertama di Indonesia.
# Out:
# Overwriting lokasi_semarang.csv

# %% [markdown]
# Praktikum 2

# %%
import pandas as pd

NAMA_FILE_CSV = "lokasi_semarang.csv"

def baca_data_lokasi(nama_file: str) -> pd.DataFrame | None:
    print(f"Mencoba membaca file CSV: {nama_file}")
    try:
        dataframe = pd.read_csv(nama_file)
        print(" -> File CSV berhasil dibaca.")
        return dataframe
    except Exception as e:
        print(f" -> ERROR saat membaca file CSV: {e}")
        return None

# Eksekusi Pembacaan
df_lokasi = baca_data_lokasi(NAMA_FILE_CSV)
print(f"\nDimensi Data: {df_lokasi.shape[0]} Baris, {df_lokasi.shape[1]} Kolom")
# Out:
# Mencoba membaca file CSV: lokasi_semarang.csv
#  -> File CSV berhasil dibaca.
#
# Dimensi Data: 13 Baris, 5 Kolom

# %% [markdown]
# Praktikum 3 & Penugasan A

# %%
from abc import ABC, abstractmethod

class Lokasi(ABC):
    def __init__(self, nama: str, latitude: float, longitude: float):
        self.nama = str(nama) if nama else "Tanpa Nama"
        try:
            self.latitude = float(latitude)
            self.longitude = float(longitude)
        except (ValueError, TypeError):
            self.latitude = 0.0
            self.longitude = 0.0

    def get_koordinat(self) -> tuple:
        return (self.latitude, self.longitude)

    @abstractmethod
    def get_info_popup(self) -> str:
        pass

    def __repr__(self) -> str:
        return f"{type(self).__name__}(nama='{self.nama}', lat={self.latitude:.4f}, lon={self.longitude:.4f})"


class TempatWisata(Lokasi):
    def __init__(self, nama: str, latitude: float, longitude: float, jenis: str, deskripsi: str):
        super().__init__(nama, latitude, longitude)
        self.jenis_wisata = str(jenis) if jenis else "Umum"
        self.deskripsi = str(deskripsi) if deskripsi else "Tidak ada deskripsi."

    def get_info_popup(self) -> str:
        return f"<h4><b>{self.nama}</b></h4><i>{self.jenis_wisata}</i><br><br>{self.deskripsi}"


class Kuliner(Lokasi):
    def __init__(self, nama: str, latitude: float, longitude: float, menu_andalan: str):
        super().__init__(nama, latitude, longitude)
        self.menu_andalan = str(menu_andalan) if menu_andalan else "Tidak diketahui"

    def get_info_popup(self) -> str:
        return f"<h4><b>{self.nama}</b></h4><i>Kuliner</i><br><br>Menu Andalan: {self.menu_andalan}"


class TempatIbadah(Lokasi):
    def __init__(self, nama: str, latitude: float, longitude: float, agama: str = "Umum", deskripsi: str = ""):
        super().__init__(nama, latitude, longitude)
        self.agama = str(agama) if agama else "Umum"
        self.deskripsi = str(deskripsi) if deskripsi else "Tempat Ibadah"

    def get_info_popup(self) -> str:
        return f"<h4><b>{self.nama}</b></h4><i>Tempat Ibadah ({self.agama})</i><br><br>{self.deskripsi}"


# KELAS BARU UNTUK PENUGASAN A
class Museum(Lokasi):
    def __init__(self, nama: str, latitude: float, longitude: float, deskripsi: str):
        super().__init__(nama, latitude, longitude)
        self.deskripsi = str(deskripsi) if deskripsi else "Museum Sejarah"

    def get_info_popup(self) -> str:
        return f"<h4><b>{self.nama}</b></h4><i>🏛️ Museum</i><br><br>{self.deskripsi}"

print("Struktur Kelas OOP (Termasuk Kelas Museum) berhasil dimuat.")
# Out:
# Struktur Kelas OOP (Termasuk Kelas Museum) berhasil dimuat.

# %%
def buat_objek_lokasi_dari_df(dataframe: pd.DataFrame) -> list:
    list_objek_lokasi = []
    if dataframe is None or dataframe.empty:
        return list_objek_lokasi

    for index, row in dataframe.iterrows():
        nama = row.get('Nama', None)
        lat = row.get('Latitude', None)
        lon = row.get('Longitude', None)
        tipe = row.get('Tipe', 'Lainnya')
        deskripsi = row.get('Deskripsi', '')

        if nama is None or lat is None or lon is None:
            continue

        # Mengenali tipe 'Museum' dan melahirkannya menjadi objek Museum
        if tipe == 'Museum':
            objek = Museum(nama, lat, lon, deskripsi)
        elif 'Wisata' in tipe or tipe == 'Landmark' or tipe == 'Taman Kota':
            objek = TempatWisata(nama, lat, lon, tipe, deskripsi)
        elif tipe == 'Kuliner':
            objek = Kuliner(nama, lat, lon, deskripsi)
        elif 'Ibadah' in tipe:
            agama_info = "Islam" if "Masjid" in nama else "Tridharma" if "Klenteng" in nama else "Umum"
            objek = TempatIbadah(nama, lat, lon, agama_info, deskripsi)
        else:
            objek = TempatWisata(nama, lat, lon, "Umum", deskripsi)

        list_objek_lokasi.append(objek)

    return list_objek_lokasi

# Eksekusi Transformasi Objek
list_semua_lokasi = buat_objek_lokasi_dari_df(df_lokasi)

print("--- Hasil Cetak Objek Instansiasi ---")
for lok in list_semua_lokasi:
    print(repr(lok)) # Perhatikan tipe Museum(nama=...) sekarang pasti tercetak!
# Out:
# --- Hasil Cetak Objek Instansiasi ---
# TempatWisata(nama='Lawang Sewu', lat=-6.9840, lon=110.4105)
# TempatWisata(nama='Simpang Lima', lat=-6.9929, lon=110.4200)
# TempatIbadah(nama='Masjid Agung Jawa Tengah', lat=-6.9892, lon=110.4452)
# TempatIbadah(nama='Klenteng Sam Poo Kong', lat=-6.9980, lon=110.4030)
# TempatWisata(nama='Brown Canyon', lat=-7.0375, lon=110.4875)
# Kuliner(nama='Lumpia Gang Lombok', lat=-6.9718, lon=110.4255)
# TempatWisata(nama='Kota Lama', lat=-6.9690, lon=110.4250)
# TempatWisata(nama='Pantai Marina', lat=-6.9585, lon=110.3875)
# TempatWisata(nama='Kampoeng Kopi Banaran', lat=-7.2780, lon=110.4010)
# Kuliner(nama='Toko Oen', lat=-6.9715, lon=110.4235)
# Museum(nama='Museum Ranggawarsita', lat=-7.0012, lon=110.3842)
# Museum(nama='Museum Mandala Bhakti', lat=-6.9845, lon=110.4092)
# TempatWisata(nama='Taman Indonesia Kaya', lat=-6.9921, lon=110.4225)

# %% [markdown]
# Praktikum 6 - Log & Penugasan

# %%
# %%writefile config_peta.txt
# -6.9929
# 110.4200
# 13
#
# import datetime
#
# def tulis_log(pesan: str, file_log: str = "proses_peta.log"):
#     timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
#     try:
#         with open(file_log, 'a', encoding='utf-8') as f:
#             f.write(f"[{timestamp}] {pesan}\n")
#     except IOError as e:
#         print(f"Gagal menulis log: {e}")
# Out:
# Overwriting config_peta.txt

# %% [markdown]
# Praktikum 5 - Visualisasi Peta Semarang

# %%
import folium

def buat_peta_lokasi_folium(list_objek: list, file_output: str = "peta_lokasi.html"):
    # Baca Konfigurasi Peta dari Berkas Teks (Penugasan C)
    try:
        with open("config_peta.txt", "r") as f:
            lines = f.readlines()
            lat_tengah = float(lines[0].strip())
            lon_tengah = float(lines[1].strip())
            zoom_awal = int(lines[2].strip())
        print(f"✅ Konfigurasi file aktif: Pusat ({lat_tengah}, {lon_tengah}), Zoom: {zoom_awal}")
    except Exception:
        lat_tengah, lon_tengah, zoom_awal = -6.9929, 110.4200, 12

    peta_akhir = folium.Map(location=[lat_tengah, lon_tengah], zoom_start=zoom_awal)

    # Menambahkan marker berdasarkan pengecekan jenis objek murni (Penugasan B)
    for lok in list_objek:
        koordinat = lok.get_koordinat()
        if koordinat == (0.0, 0.0):
            continue

        # Menggunakan isinstance() untuk menentukan warna kustomisasi penanda
        if isinstance(lok, Museum):
            warna_pin = 'purple'    # Ungu khusus Museum
        elif isinstance(lok, TempatWisata):
            warna_pin = 'blue'      # Biru untuk Tempat Wisata / Taman
        elif isinstance(lok, Kuliner):
            warna_pin = 'red'       # Merah untuk tempat makan Kuliner
        elif isinstance(lok, TempatIbadah):
            warna_pin = 'green'     # Hijau untuk Tempat Ibadah
        else:
            warna_pin = 'gray'

        folium.Marker(
            location=koordinat,
            popup=folium.Popup(lok.get_info_popup(), max_width=300),
            tooltip=lok.nama,
            icon=folium.Icon(color=warna_pin)
        ).add_to(peta_akhir)

    peta_akhir.save(file_output)
    tulis_log(f"Peta '{file_output}' berhasil disimpan.")
    return peta_akhir

# Panggil fungsi untuk memunculkan peta secara visual langsung di Google Colab
peta_tampil = buat_peta_lokasi_folium(list_semua_lokasi)
peta_tampil
# Out:
# ✅ Konfigurasi file aktif: Pusat (-6.9929, 110.42), Zoom: 13
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a00d6882d97c3900bb62416739cd47ac {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a00d6882d97c3900bb62416739cd47ac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a00d6882d97c3900bb62416739cd47ac = L.map(
#                 &quot;map_a00d6882d97c3900bb62416739cd47ac&quot;,
#                 {
#                     center: [-6.9929, 110.42],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_235ea7b23ed423a46cc2f3a1d24a3b6e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_235ea7b23ed423a46cc2f3a1d24a3b6e.addTo(map_a00d6882d97c3900bb62416739cd47ac);
#
#
#             var marker_743bcbb23001c4195abad9854e077ea9 = L.marker(
#                 [-6.984, 110.4105],
#                 {
# }
#             ).addTo(map_a00d6882d97c3900bb62416739cd47ac);
#
#
#             var icon_f93a7d3df4ddc3262b42394b6f64b0cb = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_1357706e6994b6302ba934dd60457373 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_77b4c28d4f67ae18dfbc89d3c981ce87 = $(`&lt;div id=&quot;html_77b4c28d4f67ae18dfbc89d3c981ce87&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h4&gt;&lt;b&gt;Lawang Sewu&lt;/b&gt;&lt;/h4&gt;&lt;i&gt;Wisata Sejarah&lt;/i&gt;&lt;br&gt;&lt;br&gt;Bangunan bersejarah peninggalan Belanda dengan banyak pintu.&lt;/div&gt;`)[0];
#                 popup_1357706e6994b6302ba934dd60457373.setContent(html_77b4c28d4f67ae18dfbc89d3c981ce87);
#
#
#
#         marker_743bcbb23001c4195abad9854e077ea9.bindPopup(popup_1357706e6994b6302ba934dd60457373)
#         ;
#
#
#
#
#             marker_743bcbb23001c4195abad9854e077ea9.bindTooltip(
#                 `&lt;div&gt;
#                      Lawang Sewu
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_743bcbb23001c4195abad9854e077ea9.setIcon(icon_f93a7d3df4ddc3262b42394b6f64b0cb);
#
#
#             var marker_b390aba38af9878e301929e535e5520e = L.marker(
#                 [-6.9929, 110.42],
#                 {
# }
#             ).addTo(map_a00d6882d97c3900bb62416739cd47ac);
#
#
#             var icon_911668032ffcffe73f05afdbe3b69339 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_6d4c904c9d937d27cd27877c1085ff96 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_8cf6f4839a1a72bd1df7cf191f3e9513 = $(`&lt;div id=&quot;html_8cf6f4839a1a72bd1df7cf191f3e9513&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h4&gt;&lt;b&gt;Simpang Lima&lt;/b&gt;&lt;/h4&gt;&lt;i&gt;Landmark&lt;/i&gt;&lt;br&gt;&lt;br&gt;Alun-alun pusat kota Semarang, tempat berkumpul populer.&lt;/div&gt;`)[0];
#                 popup_6d4c904c9d937d27cd27877c1085ff96.setContent(html_8cf6f4839a1a72bd1df7cf191f3e9513);
#
#
#
#         marker_b390aba38af9878e301929e535e5520e.bindPopup(popup_6d4c904c9d937d27cd27877c1085ff96)
#         ;
#
#
#
#
#             marker_b390aba38af9878e301929e535e5520e.bindTooltip(
#                 `&lt;div&gt;
#                      Simpang Lima
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_b390aba38af9878e301929e535e5520e.setIcon(icon_911668032ffcffe73f05afdbe3b69339);
#
#
#             var marker_19652807834c6ab9379bf8e425e8128c = L.marker(
#                 [-6.9892, 110.4452],
#                 {
# }
#             ).addTo(map_a00d6882d97c3900bb62416739cd47ac);
#
#
#             var icon_73e2e0e11ac1770a5ba3765b8416372f = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_e08c2f33a0da80543981f
